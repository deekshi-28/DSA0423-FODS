# %% [markdown]
# <a href="https://colab.research.google.com/github/deekshi-28/DSA0423-FODS/blob/main/fods_activity2(3_3_26).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===============================
# Activity 2: Outlier Treatment
# ===============================

import numpy as np
import pandas as pd

# House prices in $100,000s
prices = np.array([2.5, 3.0, 2.8, 3.2, 15.0, 2.9, 3.1, 2.7, 100.0])

df = pd.DataFrame(prices, columns=["Price"])

print("Original Data:")
print(df)
# -------------------------------
# 1. Identify Outliers (Z-score)
# -------------------------------

from scipy.stats import zscore

df["Z_score"] = zscore(df["Price"])

outliers = df[np.abs(df["Z_score"]) > 3]

print("\nDetected Outliers (|Z| > 3):")
print(outliers)
# Out:
# Original Data:
#    Price
# 0    2.5
# 1    3.0
# 2    2.8
# 3    3.2
# 4   15.0
# 5    2.9
# 6    3.1
# 7    2.7
# 8  100.0
#
# Detected Outliers (|Z| > 3):
# Empty DataFrame
# Columns: [Price, Z_score]
# Index: []

# %%
# -------------------------------
# 2. Treat the 100.0 typo
# Replace 100.0 with correct 10.0
# -------------------------------

df_corrected = df.copy()
df_corrected.loc[df_corrected["Price"] == 100.0, "Price"] = 10.0

print("\nAfter Correcting 100.0 to 10.0:")
print(df_corrected)
# Out:
# After Correcting 100.0 to 10.0:
#    Price   Z_score
# 0    2.5 -0.413529
# 1    3.0 -0.397018
# 2    2.8 -0.403622
# 3    3.2 -0.390413
# 4   15.0 -0.000734
# 5    2.9 -0.400320
# 6    3.1 -0.393715
# 7    2.7 -0.406925
# 8   10.0  2.806275

# %%
# -------------------------------
# 3. Decision about 15.0
# -------------------------------

# Option 1: Keep it (legitimate mansion)
print("\nKeeping 15.0 since it is legitimate.")

# Optional: Cap extreme values (example using 95th percentile)

upper_cap = np.percentile(df_corrected["Price"], 95)
df_corrected["Capped_Price"] = np.where(
    df_corrected["Price"] > upper_cap,
    upper_cap,
    df_corrected["Price"]
)

print("\nData after optional capping at 95th percentile:")
print(df_corrected)
# Out:
# Keeping 15.0 since it is legitimate.
#
# Data after optional capping at 95th percentile:
#    Price   Z_score  Capped_Price
# 0    2.5 -0.413529           2.5
# 1    3.0 -0.397018           3.0
# 2    2.8 -0.403622           2.8
# 3    3.2 -0.390413           3.2
# 4   15.0 -0.000734          13.0
# 5    2.9 -0.400320           2.9
# 6    3.1 -0.393715           3.1
# 7    2.7 -0.406925           2.7
# 8   10.0  2.806275          10.0
